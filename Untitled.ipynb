# %%
"""
run.py  (Module 2 — Tidal Locking & Rotation)
================================================
Jupyter-friendly entry point for the Tidal Locking analysis module.

Configure the switches below then run in Jupyter:
    # %run module_2_tidal_rotation/run.py
or in terminal:
    python module_2_tidal_rotation/run.py

TIDAL_MODE selects between two distinct analysis pipelines:
  "lightcurve" — Extract stellar rotation period from TESS/Kepler photometry
                 via Lomb-Scargle periodogram and compare P_rot to P_orb.
                 This tells you if the star is rotating synchronously.
  "mcmc"       — Use the Rossiter-McLaughlin MCMC solver to fit v_sin_i and
                 spin-orbit angle lambda from Radial Velocity data.
                 This directly measures the rotation/orbit alignment.

DATA SOURCES (real observations):
  Photometry (lightcurve mode):
    - TESS: https://mast.stsci.edu/  (via lightkurve)
    - Kepler: https://mast.stsci.edu/
  Radial Velocity (mcmc mode):
    - HARPS ESO Archive: http://archive.eso.org/
    - ESPRESSO:          http://archive.eso.org/
    - HIRES Keck:        https://koa.ipac.caltech.edu/
    - NEID:              https://neid.ipac.caltech.edu/
  Transmission Spectra (super-rotation / wind):
    - CARMENES:          https://carmenes.cab.inta-csic.es/
    - CRIRES+:           http://archive.eso.org/
"""

import os
import sys
import numpy as np

# ─────────────────────────────────────────────────────────────────────
# CONFIGURATION — Edit these for your run
# ─────────────────────────────────────────────────────────────────────

# Get directory of this script (fallback for Jupyter)
try:
    _here = os.path.dirname(os.path.abspath(__file__))
except NameError:
    _here = os.getcwd()

# -- Batch Mode -------------------------------------------------------
# Set BATCH_MODE = True to process the entire HWO target Excel sheet.
# When True, single-planet MCMC / lightcurve sections are skipped.
BATCH_MODE      = True
BATCH_EXCEL     = os.path.join(_here, "hwo_targets.xlsx")  # generated by create_hwo_sheet.py
ROCKY_ONLY      = False   # True = restrict batch to rocky planet rows only
RUN_CORRELATION = True    # Run empirical power-law correlation analysis after batch
BATCH_RM_MCMC   = True   # Run fast RM MCMC for every planet in batch (~3 min extra)
RM_EXTENDED     = True   # Use 4-param MCMC (v_sin_i, lambda, b, drv0) vs 2-param
RUN_DECOMPOSITION = True  # Compute Doppler decomposition (rot vs super-rot) for batch
RUN_FEASIBILITY   = True  # Compute HWO/ELT detection feasibility ranking
FEAS_INSTRUMENT   = "HWO_6m"  # "HWO_6m", "ELT_HIRES", "VLT_CRIRES"
# ---------------------------------------------------------------------

# Mode selector
TIDAL_MODE      = "mcmc"          # "lightcurve" or "mcmc"  (single-planet mode)

# Target system (used by both modes)
TARGET          = "GJ-486b"       # Any MAST name or local path

# Orbital parameters for the target (used by rotation_analyser)
A_AU            = 0.01734         # GJ 486 b semi-major axis (AU)
M_STAR_MSUN     = 0.323           # GJ 486 stellar mass
R_PLANET_REARTH = 1.305           # GJ 486 b radius
P_ORB_DAYS      = 1.467           # GJ 486 b orbital period
ECCENTRICITY    = 0.05            # GJ 486 b eccentricity
SYSTEM_AGE_GYR  = 6.6             # GJ 486 system age
PLANET_TYPE     = "rocky"

# MCMC mode parameters (from a prior photometric fit)
MCMC_P_RATIO    = 0.0806          # Rp/R_* from photometric MCMC
MCMC_A_RATIO    = 36.7            # a/R_* from photometric MCMC
MCMC_B          = 0.11            # Impact parameter
TRANSIT_T0      = 0.0             # Mid-transit reference epoch (days)

# RM MCMC settings
RM_NSTEPS       = 2000
RM_NBURN        = 400

# Synthetic dataset switch
RUN_SYNTHETIC      = True    # Show the synthetic non-locked planet demonstration
RUN_LOCKED_SYNTH   = True    # Also run the locked planet synthetic dataset (contrast)

# Output directory
OUTPUT_DIR = os.path.join(_here, "..", "output_plots", "module2")
os.makedirs(OUTPUT_DIR, exist_ok=True)

# ─────────────────────────────────────────────────────────────────────

_parent = os.path.dirname(_here)
if _parent not in sys.path:
    sys.path.insert(0, _parent)          # ← fixed: was os.path.dirname(_parent)

from module_2_tidal_rotation.rotation_analyser  import RotationAnalyser
from module_2_tidal_rotation.rm_solver          import RMSolverMCMC, RMSolverMCMCExtended
from module_2_tidal_rotation.lightcurve_tidal   import LightcurveTidalAnalyser
from module_2_tidal_rotation.synthetic_data     import (SyntheticTidalDataset,
                                                        SyntheticLockedDataset,
                                                        compare_locked_unlocked)
from module_2_tidal_rotation.batch_processor    import BatchTidalProcessor
from module_2_tidal_rotation.correlation_analysis import CorrelationAnalyser
from module_2_tidal_rotation.feasibility        import DetectionFeasibilityAnalyser
import module_2_tidal_rotation.plots as plots


def section(title):
    print(f"\n{'='*70}")
    print(f"  {title}")
    print(f"{'='*70}\n")


# ── 1. Rotation State Analysis (always runs) ─────────────────────────
section("1. ROTATION STATE ANALYSIS")

ra    = RotationAnalyser()
state = ra.full_analysis(
    a_AU=A_AU, M_star_Msun=M_STAR_MSUN,
    R_planet_Rearth=R_PLANET_REARTH,
    eccentricity=ECCENTRICITY,
    system_age_gyr=SYSTEM_AGE_GYR,
    planet_type=PLANET_TYPE,
    P_orbital_days=P_ORB_DAYS,
)
ra.print_report(state)

# Tidal sensitivity heatmap
plots.plot_sensitivity_heatmap(
    state["sensitivity"],
    save_path=os.path.join(OUTPUT_DIR, "tidal_sensitivity_heatmap.png")
)


# ── 2a. Lightcurve Mode ───────────────────────────────────────────────
if TIDAL_MODE == "lightcurve":
    section(f"2. LIGHTCURVE TIDAL MODE — {TARGET}")

    lta = LightcurveTidalAnalyser()

    if os.path.exists(TARGET):
        lc = lta.load_local(TARGET)
    else:
        lc = lta.download(TARGET)

    rot = lta.find_rotation_period(lc, method="lomb_scargle")
    lock_state = lta.assess_locking(rot["P_rot_days"], P_ORB_DAYS,
                                    system_age_gyr=SYSTEM_AGE_GYR)
    lta.print_report(lock_state)


# ── 2b. MCMC RM Mode ─────────────────────────────────────────────────
elif TIDAL_MODE == "mcmc":
    section(f"2. MCMC ROSSITER-MCLAUGHLIN MODE — {TARGET}")

    rm = RMSolverMCMC(nsteps=RM_NSTEPS, nburn=RM_NBURN)

    # Derive tight RV observation window from transit geometry
    b_s = min(abs(MCMC_B), 0.999)
    p_s = max(MCMC_P_RATIO, 0.001)
    a_s = MCMC_A_RATIO
    x_c_max  = float(np.sqrt((1.0 + p_s)**2 - b_s**2))
    if a_s <= x_c_max:
        a_s = x_c_max * 1.5
    phase_lim = float(np.arcsin(x_c_max / a_s)) / (2 * np.pi)
    t_limit   = phase_lim * P_ORB_DAYS
    t_rv      = np.linspace(TRANSIT_T0 - t_limit * 1.2,
                             TRANSIT_T0 + t_limit * 1.2, 100)

    # Generate synthetic-but-physically-derived RV signal (seeded from MCMC geometry)
    v_sin_i_true = 3.5
    lam_true     = np.radians(8.0)
    from module_2_tidal_rotation.rm_solver import RMSolverMCMC as _rm
    rv_true_model = _rm.ohta_rm_profile(
        t_rv, TRANSIT_T0, P_ORB_DAYS,
        v_sin_i_true, lam_true, p_s, a_s, b_s
    )
    sig_amp    = float(np.max(np.abs(rv_true_model))) or 0.005
    base_noise = sig_amp * 0.15
    # Variable heteroscedastic noise based on a baseline noise + random variation per point
    rv_err     = base_noise * (1.0 + 0.5 * np.random.uniform(-1, 1, len(t_rv)))
    rv_obs     = rv_true_model + np.random.normal(0, rv_err)

    # Run MCMC
    rm_results, rm_samples = rm.run_mcmc(
        t_rv, rv_obs, rv_err,
        MCMC_P_RATIO, a_s, b_s, TRANSIT_T0, P_ORB_DAYS
    )

    # Compute best-fit model curve
    rv_fit = rm.ohta_rm_profile(
        t_rv, TRANSIT_T0, P_ORB_DAYS,
        rm_results["v_sin_i"]["median"],
        rm_results["lambda_rad"]["median"],
        p_s, a_s, b_s
    )

    # Plots
    plots.plot_rm_anomaly(
        t_rv, rv_obs, rv_err, rv_fit, rm_results, TRANSIT_T0, TARGET,
        save_path=os.path.join(OUTPUT_DIR, "rm_anomaly.png")
    )
    plots.plot_rm_corner(
        rm_samples,
        save_path=os.path.join(OUTPUT_DIR, "rm_corner.png")
    )

else:
    print(f"Unknown TIDAL_MODE '{TIDAL_MODE}'. Use 'lightcurve' or 'mcmc'.")



# -- 3. Synthetic Non-Locked Planet Demo ------------------------------
if RUN_SYNTHETIC:
    section("3. SYNTHETIC DEMO - Non-Tidally-Locked Planet")

    ds = SyntheticTidalDataset()
    ds.print_summary()

    rv_data   = ds.generate_rv_timeseries()
    spec_data = ds.generate_transmission_spectra()

    plots.plot_synthetic_rv(
        rv_data,
        save_path=os.path.join(OUTPUT_DIR, "synthetic_unlocked_rv.png")
    )
    plots.plot_transmission_spectra(
        spec_data,
        save_path=os.path.join(OUTPUT_DIR, "synthetic_transmission_spectra.png")
    )

# -- 3b. Locked + Unlocked contrast -----------------------------------
if RUN_LOCKED_SYNTH:
    section("3b. SYNTHETIC DEMO - Locked vs Unlocked Comparison")

    locked_ds = SyntheticLockedDataset()
    locked_ds.print_summary()

    comparison = compare_locked_unlocked()
    plots.plot_locked_unlocked_comparison(
        comparison,
        save_path=os.path.join(OUTPUT_DIR, "locked_vs_unlocked_comparison.png")
    )
    plots.plot_synthetic_rv(
        comparison["locked"]["rv_data"],
        save_path=os.path.join(OUTPUT_DIR, "synthetic_locked_rv.png")
    )
    plots.plot_transmission_spectra(
        comparison["locked"]["spec_data"],
        save_path=os.path.join(OUTPUT_DIR, "synthetic_locked_transmission.png")
    )

# ── 4. Sensitivity Analysis ───────────────────────────────────────────
section("4. SENSITIVITY ANALYSIS")

_DAY_S = 86400.0

# 4a. tau_sync vs semi-major axis for 3 planet types
a_range = np.logspace(np.log10(0.005), np.log10(1.0), 200)
tau_by_type = {}
for _ptype in ["rocky", "ice_giant", "gas_giant"]:
    tau_by_type[_ptype] = np.array([
        ra.sync_timescale(a, M_STAR_MSUN, R_PLANET_REARTH, planet_type=_ptype)["tau_sync_Gyr"]
        for a in a_range
    ])

plots.plot_tidal_evolution(
    a_range, tau_by_type, SYSTEM_AGE_GYR, A_AU,
    save_path=os.path.join(OUTPUT_DIR, "tidal_evolution.png")
)

# 4b. Pseudo-synchronous rotation ratio vs eccentricity
ecc_range = np.linspace(0.0, 0.85, 300)
n_orb     = 2.0 * np.pi / (P_ORB_DAYS * _DAY_S)
ps_ratios = np.array([ra.pseudo_sync_rate(n_orb, e)["ratio_to_sync"] for e in ecc_range])

plots.plot_pseudo_sync_ecc(
    ecc_range, ps_ratios, ECCENTRICITY,
    save_path=os.path.join(OUTPUT_DIR, "pseudo_sync_ecc.png")
)

# 4c. Full 6-panel sensitivity dashboard
R_range      = np.linspace(0.5, 4.0, 120)
tau_vs_R     = np.array([ra.sync_timescale(A_AU, M_STAR_MSUN, R, planet_type="rocky")["tau_sync_Gyr"]
                          for R in R_range])

Mstar_range  = np.linspace(0.08, 2.0, 120)
tau_vs_Mstar = np.array([ra.sync_timescale(A_AU, M, R_PLANET_REARTH, planet_type="rocky")["tau_sync_Gyr"]
                          for M in Mstar_range])

Q_range      = np.logspace(1, 6, 120)
k2_vals_sens = [0.1, 0.299, 0.5]
tau_vs_Q     = {k2: np.array([
                    ra.sync_timescale(A_AU, M_STAR_MSUN, R_PLANET_REARTH, Q=Q, k2=k2)["tau_sync_Gyr"]
                    for Q in Q_range])
                for k2 in k2_vals_sens}

sens_results = {
    "a_range":       a_range,
    "tau_by_type":   tau_by_type,
    "ecc_range":     ecc_range,
    "ps_ratios":     ps_ratios,
    "R_range":       R_range,
    "tau_vs_R":      tau_vs_R,
    "Mstar_range":   Mstar_range,
    "tau_vs_Mstar":  tau_vs_Mstar,
    "Q_range":       Q_range,
    "tau_vs_Q":      tau_vs_Q,
    "k2_vals_sens":  k2_vals_sens,
    "sens_grid":     state["sensitivity"],
    "system_age_gyr": SYSTEM_AGE_GYR,
    "planet_a_AU":   A_AU,
    "planet_ecc":    ECCENTRICITY,
    "planet_R":      R_PLANET_REARTH,
    "planet_Mstar":  M_STAR_MSUN,
}

plots.plot_sensitivity_dashboard(
    sens_results,
    save_path=os.path.join(OUTPUT_DIR, "sensitivity_dashboard.png")
)


# ── 5. Batch HWO Population Mode ─────────────────────────────────────
if BATCH_MODE:
    section("5. BATCH HWO POPULATION ANALYSIS")

    # 5a. Generate Excel sheet if it doesn't exist yet
    if not os.path.exists(BATCH_EXCEL):
        print(f"  Excel sheet not found at {BATCH_EXCEL}")
        print("  Run:  python module_2_tidal_rotation/create_hwo_sheet.py")
        print("  ...or set BATCH_EXCEL to your own sheet path.")
    else:
        BATCH_DIR = os.path.join(OUTPUT_DIR, "batch")
        os.makedirs(BATCH_DIR, exist_ok=True)
        BATCH_CSV = os.path.join(BATCH_DIR, "batch_results.csv")

        # 5b. Run batch tidal analysis
        bp  = BatchTidalProcessor(BATCH_EXCEL)
        df_batch = bp.run(
            planet_types=["rocky"] if ROCKY_ONLY else None,
            verbose=True
        )
        bp.save(df_batch, BATCH_CSV)

        # 5c. Population-level plots (locking map + wind signatures)
        plots.plot_batch_locking_map(
            df_batch,
            boundary=None,   # will be updated after correlation step
            save_path=os.path.join(BATCH_DIR, "batch_locking_map.png")
        )
        plots.plot_wind_signature_population(
            df_batch,
            save_path=os.path.join(BATCH_DIR, "wind_signature_population.png")
        )

        # 5d. Empirical correlation analysis
        if RUN_CORRELATION:
            section("5d. EMPIRICAL CORRELATION ANALYSIS")
            ca = CorrelationAnalyser(BATCH_CSV)
            corr_results = ca.run_all(
                plot_dir=BATCH_DIR,
                rocky_only=ROCKY_ONLY
            )

            # Re-draw locking map with empirical boundary overplotted
            if corr_results["boundary"]:
                plots.plot_batch_locking_map(
                    df_batch,
                    boundary=corr_results["boundary"],
                    save_path=os.path.join(BATCH_DIR, "batch_locking_map_boundary.png")
                )

            # LaTeX-ready results table
            print("\n  LaTeX table (rocky planets):")
            ca.print_latex_table(corr_results["df"], rocky_only=True)

        # 5e. Batch RM MCMC (per-planet RV anomaly + MCMC plots)
        if BATCH_RM_MCMC:
            section("5e. BATCH RM MCMC - Per-Planet RV Anomaly")
            df_batch_rm = bp.run_rm_batch(
                df_batch,
                out_dir=BATCH_DIR,
                nsteps=10000,   # rigorous — takes time but gives clean posteriors
                nburn=3000,
                extended=RM_EXTENDED,
                verbose=True
            )
            bp.save(df_batch_rm,
                    os.path.join(BATCH_DIR, "batch_results_with_rm.csv"))

            # Gallery figure (all RV anomaly plots in one page)
            rv_dir = os.path.join(BATCH_DIR, "rv_anomaly")
            plots.plot_rv_anomaly_gallery(
                rv_dir,
                planet_names=df_batch["planet_name"].tolist(),
                save_path=os.path.join(BATCH_DIR, "rv_anomaly_gallery.png")
            )

        # 5f. Doppler Decomposition
        if RUN_DECOMPOSITION and "dv_total_kms" in df_batch.columns:
            section("5f. DOPPLER DECOMPOSITION - Rotation vs Super-Rotation")
            plots.plot_doppler_decomposition(
                df_batch,
                save_path=os.path.join(BATCH_DIR, "doppler_decomposition.png")
            )
            # Print summary stats
            n_rot_dom = df_batch["rot_dominates"].sum() if "rot_dominates" in df_batch.columns else 0
            print(f"  Rotation-dominated planets: {n_rot_dom}/{len(df_batch)}")
            print(f"  Mean dv_total = {df_batch['dv_total_kms'].mean():.4f} km/s")

        # 5g. Detection Feasibility Ranking
        if RUN_FEASIBILITY and "dv_total_kms" in df_batch.columns:
            section("5g. DETECTION FEASIBILITY RANKING")
            dfa = DetectionFeasibilityAnalyser(df_batch)
            df_feas = dfa.run(instrument=FEAS_INSTRUMENT)
            dfa.print_priority_table(df_feas, top_n=20)
            df_feas.to_csv(
                os.path.join(BATCH_DIR, "detection_feasibility.csv"), index=False
            )
            plots.plot_detection_feasibility(
                df_feas, df_batch=df_batch,
                save_path=os.path.join(BATCH_DIR, "detection_feasibility.png")
            )

        print(f"\n  Batch outputs saved to: {BATCH_DIR}")


section("MODULE 2 COMPLETE")
print(f"  All outputs saved to: {OUTPUT_DIR}")
# Out:
# C:\Users\asmit\anaconda3\Lib\site-packages\lightkurve\prf\__init__.py:7: UserWarning: Warning: the tpfmodel submodule is not available without oktopus installed, which requires a current version of autograd. See #1452 for details.
#   warnings.warn(
# ======================================================================
#   1. ROTATION STATE ANALYSIS
# ======================================================================
#
#
# ==============================================================
#   ROTATION STATE ANALYSIS
# ==============================================================
#   Orbital period:      1.4670 days
#   Eccentricity:        0.0500
#   System age:          6.60 Gyr
#   tau_sync:            4.618e-08 Gyr
#   Age / tau_sync:      1.429e+08
#   Pseudo-sync period:  1.4453 days
#   Pseudo-sync / sync:  1.0150
#   State: Pseudo-synchronous (eccentric lock)
#   Resonance Matches:
#     1:1 synchronous (tidally locked) (deviation 1.50%)
#   Q-k2 sensitivity:    100% of Q-k2 scenarios predict locking
# ==============================================================
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\tidal_sensitivity_heatmap.png
#
# ======================================================================
#   2. MCMC ROSSITER-MCLAUGHLIN MODE — GJ-486b
# ======================================================================
#
# [RMSolverMCMC] Pre-fitting with curve_fit...
#   Seed: v_sin_i=3.45 km/s  lambda=13.5 deg
# [RMSolverMCMC] Running 2000 iterations...
# 100%|█████████████████████████████████████████████████████████████████████████████| 2000/2000 [00:05<00:00, 339.80it/s]
# [RMSolverMCMC] Done.
#   v sin i = 3.46 +0.14/-0.12 km/s
#   lambda  = 13.5 +6.9/-7.3 deg
#   State:    Aligned — consistent with tidal synchronization
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\rm_anomaly.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\rm_corner.png
#
# ======================================================================
#   3. SYNTHETIC DEMO - Non-Tidally-Locked Planet
# ======================================================================
#
#
# ============================================================
#   SYNTHETIC DATASET -- Non-Tidally-Locked Planet
# ============================================================
#   System:             SyntheticB (Non-Locked Demo)
#   Orbital semi-major: 0.15 AU
#   Orbital period:     30.0 days
#   Rotation period:    18.0 days  (NOT = P_orb!)
#   Eccentricity:       0.05
#   System age:         5.0 Gyr
#
#   Atmospheric Wind Signature:
#     Ingress (morning limb):  v = +1.80 km/s  [REDSHIFT -- wind receding]
#     Egress  (evening limb):  v = -2.20 km/s  [BLUESHIFT -- wind approaching]
#     Delta_v:                 +4.00 km/s  -> Super-rotation JET confirmed
#     Net disk blueshift:      -0.20 km/s
#
#   Data sources for REAL systems:
#     Photometric RV: HARPS (ESO Archive) / ESPRESSO / HIRES
#     Transmission:   CARMENES / CRIRES+ / SPIRou
# ============================================================
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\synthetic_unlocked_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\synthetic_transmission_spectra.png
#
# ======================================================================
#   3b. SYNTHETIC DEMO - Locked vs Unlocked Comparison
# ======================================================================
#
#
# ============================================================
#   SYNTHETIC DATASET -- Tidally-LOCKED Planet
# ============================================================
#   System:             SyntheticA (Locked Demo)
#   Orbital semi-major: 0.04 AU
#   Orbital period:     8.0 days
#   Rotation period:    8.0 days  (= P_orb: LOCKED)
#   System age:         8.0 Gyr  (deeply locked)
#
#   Atmospheric Wind Signature (SYMMETRIC):
#     Ingress (morning limb):  v = +0.10 km/s
#     Egress  (evening limb):  v = -0.10 km/s
#     Delta_v:                 +0.20 km/s  -> Co-rotating atmosphere, NO jet
#   RM effect:  v sin i = 2.0 km/s, lambda = 0.0 deg
# ============================================================
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\locked_vs_unlocked_comparison.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\synthetic_locked_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\synthetic_locked_transmission.png
#
# ======================================================================
#   4. SENSITIVITY ANALYSIS
# ======================================================================
#
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\tidal_evolution.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\pseudo_sync_ecc.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\sensitivity_dashboard.png
#
# ======================================================================
#   5. BATCH HWO POPULATION ANALYSIS
# ======================================================================
#
#   [  1/70] HD 3651 b ... LOCKED  (age/tau = 70.4)
#   [  2/70] HD 9826 b ... LOCKED  (age/tau = 442)
#   [  3/70] HD 9826 c ... free    (age/tau = 0.0005)
#   [  4/70] HD 9826 d ... free    (age/tau = 0)
#   [  5/70] HD 10647 b ... free    (age/tau = 0)
#   [  6/70] HD 10700 g ... LOCKED  (age/tau = 2.96e+03)
#   [  7/70] HD 10700 h ... LOCKED  (age/tau = 82.8)
#   [  8/70] HD 10700 e ... LOCKED  (age/tau = 1.26)
#   [  9/70] HD 10700 f ... free    (age/tau = 0.0054)
#   [ 10/70] HD 17051 b ... free    (age/tau = 0.0001)
#   [ 11/70] HD 20794 b ... LOCKED  (age/tau = 7.5e+03)
#   [ 12/70] HD 20794 c ... LOCKED  (age/tau = 221)
#   [ 13/70] HD 20794 d ... LOCKED  (age/tau = 16)
#   [ 14/70] HD 20794 e ... LOCKED  (age/tau = 2.7)
#   [ 15/70] HD 22049 b ... free    (age/tau = 0)
#   [ 16/70] HD 26965 b ... LOCKED  (age/tau = 481)
#   [ 17/70] HD 33564 b ... free    (age/tau = 0.0011)
#   [ 18/70] HD 39091 c ... LOCKED  (age/tau = 2.43e+05)
#   [ 19/70] HD 39091 d ... free    (age/tau = 0.564)
#   [ 20/70] HD 39091 b ... free    (age/tau = 0)
#   [ 21/70] HD 69830 b ... LOCKED  (age/tau = 5.93e+04)
#   [ 22/70] HD 69830 c ... LOCKED  (age/tau = 375)
#   [ 23/70] HD 69830 d ... free    (age/tau = 0.345)
#   [ 24/70] HD 75732 e ... LOCKED  (age/tau = 9.16e+09)
#   [ 25/70] HD 75732 b ... LOCKED  (age/tau = 19.2)
#   [ 26/70] HD 75732 c ... LOCKED  (age/tau = 383)
#   [ 27/70] HD 75732 f ... free    (age/tau = 0.309)
#   [ 28/70] HD 75732 d ... free    (age/tau = 0)
#   [ 29/70] HD 95128 b ... free    (age/tau = 0)
#   [ 30/70] HD 95128 c ... free    (age/tau = 0)
#   [ 31/70] HD 95128 d ... free    (age/tau = 0)
#   [ 32/70] HD 95735 b ... LOCKED  (age/tau = 2.06e+03)
#   [ 33/70] HD 95735 c ... free    (age/tau = 0)
#   [ 34/70] HD 102365 b ... LOCKED  (age/tau = 1.43)
#   [ 35/70] HD 114613 b ... free    (age/tau = 0)
#   [ 36/70] HD 115404A b ... LOCKED  (age/tau = 6.59e+03)
#   [ 37/70] HD 115404A c ... free    (age/tau = 0)
#   [ 38/70] HD 115617 b ... LOCKED  (age/tau = 3.73e+06)
#   [ 39/70] HD 115617 c ... LOCKED  (age/tau = 198)
#   [ 40/70] HD 115617 d ... LOCKED  (age/tau = 2.16)
#   [ 41/70] HD 136352 b ... LOCKED  (age/tau = 3.76e+04)
#   [ 42/70] HD 136352 c ... LOCKED  (age/tau = 299)
#   [ 43/70] HD 136352 d ... LOCKED  (age/tau = 8.26)
#   [ 44/70] HD 141004 b ... LOCKED  (age/tau = 6.35e+03)
#   [ 45/70] HD 140901 b ... LOCKED  (age/tau = 3.49e+04)
#   [ 46/70] HD 140901 c ... free    (age/tau = 0)
#   [ 47/70] HD 143761 e ... LOCKED  (age/tau = 6.1e+04)
#   [ 48/70] HD 143761 b ... free    (age/tau = 0.732)
#   [ 49/70] HD 143761 c ... LOCKED  (age/tau = 9.72)
#   [ 50/70] HD 143761 d ... free    (age/tau = 0.137)
#   [ 51/70] HD 147513 b ... free    (age/tau = 0)
#   [ 52/70] HD 160691 d ... LOCKED  (age/tau = 3.16e+04)
#   [ 53/70] HD 160691 e ... free    (age/tau = 0)
#   [ 54/70] HD 160691 b ... free    (age/tau = 0)
#   [ 55/70] HD 160691 c ... free    (age/tau = 0)
#   [ 56/70] HD 189567 b ... LOCKED  (age/tau = 4.02e+04)
#   [ 57/70] HD 189567 c ... LOCKED  (age/tau = 1.11e+03)
#   [ 58/70] HD 190360 c ... LOCKED  (age/tau = 6.95e+03)
#   [ 59/70] HD 190360 b ... free    (age/tau = 0)
#   [ 60/70] HD 192310 b ... LOCKED  (age/tau = 16.1)
#   [ 61/70] HD 192310 c ... free    (age/tau = 0.0084)
#   [ 62/70] HD 209100 b ... free    (age/tau = 0)
#   [ 63/70] HD 217987 b ... LOCKED  (age/tau = 9.88e+04)
#   [ 64/70] HD 217987 c ... LOCKED  (age/tau = 5.16e+03)
#   [ 65/70] HD 219134 b ... LOCKED  (age/tau = 1.77e+07)
#   [ 66/70] HD 219134 c ... LOCKED  (age/tau = 7.25e+05)
#   [ 67/70] HD 219134 f ... LOCKED  (age/tau = 1.15e+04)
#   [ 68/70] HD 219134 d ... LOCKED  (age/tau = 169)
#   [ 69/70] HD 219134 g ... LOCKED  (age/tau = 6.13)
#   [ 70/70] HD 219134 h ... free    (age/tau = 0)
#   Batch results saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\batch_results.csv
#   Locked: 41/70 planets
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\batch_locking_map.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\wind_signature_population.png
#
# ======================================================================
#   5d. EMPIRICAL CORRELATION ANALYSIS
# ======================================================================
#
#
# =================================================================
#   EMPIRICAL CORRELATION RESULTS
# =================================================================
#
#   log10(age/tau) vs log10(a):
#     alpha = -6.87 +- 0.20
#     Theory (Gladman 1996): alpha ~ -6
#     Pearson r = -0.974, Spearman r = -0.970
#
#   log10(age/tau) vs log10(R):
#     beta  = -7.72 +- 0.99
#     Theory (Gladman 1996): beta ~ +3
#     Pearson r = -0.688, Spearman r = -0.683
#
#   2D surface fit:  log10(age/tau) = -2.48 + -6.78·log10(a) + -0.22·log10(R)
#     alpha_err=0.27, beta_err=0.44
# =================================================================
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\batch_locking_map.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\empirical_fit.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\wind_signature_population.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\batch_locking_map_boundary.png
#
#   LaTeX table (rocky planets):
#
# % ── Tidal Locking Results (LaTeX) ──────────────────
# \begin{table}[ht]
# \centering
# \caption{Tidal locking analysis for rocky HWO targets.}
# \label{tab:tidal_locking}
# \begin{tabular}{lrrrrcrc}
# \hline\hline
# Planet & $a$ (AU) & $R_p$ ($R_\oplus$) & $\tau_{\rm sync}$ (Gyr) & Age/\,$\tau$ & Locked? & $f_{Q,k_2}$ & $\Delta v$ (km/s) \\
# \hline
# HD 219134 b          & 0.0385 & 1.78 & 1e-06 & 1.8e+07 & \checkmark   & 100% & 0 \\
# HD 115617 b          & 0.0502 & 2.11 & 2e-06 & 3.7e+06 & \checkmark   & 100% & 0 \\
# HD 219134 c          & 0.0648 & 1.69 & 1.5e-05 & 7.2e+05 & \checkmark   & 100% & 0 \\
# HD 217987 b          & 0.0680 & 1.88 & 4.6e-05 & 9.9e+04 & \checkmark   & 100% & 0 \\
# HD 39091 c           & 0.0680 & 1.73 & 1.1e-05 & 2.4e+05 & \checkmark   & 100% & 0 \\
# HD 95735 b           & 0.0788 & 1.45 & 0.00024 & 2.1e+03 & \checkmark   & 95% & 0 \\
# HD 136352 b          & 0.0964 & 2.02 & 0.00011 & 3.8e+04 & \checkmark   & 100% & 0 \\
# HD 143761 e          & 0.1061 & 1.77 & 0.00019 & 6.1e+04 & \checkmark   & 100% & 0 \\
# HD 189567 b          & 0.1110 & 2.85 & 0.00017 & 4e+04 & \checkmark   & 100% & 0 \\
# HD 217987 c          & 0.1200 & 2.67 & 0.00087 & 5.2e+03 & \checkmark   & 98% & 0 \\
# HD 20794 b           & 0.1270 & 1.49 & 0.00095 & 7.5e+03 & \checkmark   & 100% & 0 \\
# HD 10700 g           & 0.1330 & 1.12 & 0.002 & 3e+03 & \checkmark   & 98% & 0 \\
# HD 219134 f          & 0.1457 & 2.93 & 0.00094 & 1.1e+04 & \checkmark   & 100% & 0 \\
# HD 189567 c          & 0.1970 & 2.54 & 0.0063 & 1.1e+03 & \checkmark   & 93% & 0 \\
# HD 26965 b           & 0.2190 & 2.85 & 0.012 & 4.8e+02 & \checkmark   & 83% & 0 \\
# HD 20794 c           & 0.2250 & 1.39 & 0.032 & 2.2e+02 & \checkmark   & 81% & 0 \\
# HD 10700 h           & 0.2430 & 1.16 & 0.07 & 83 & \checkmark   & 79% & 0 \\
# HD 20794 d           & 0.3640 & 1.70 & 0.44 & 16 & \checkmark   & 64% & 0 \\
# HD 136352 d          & 0.4250 & 2.92 & 0.48 & 8.3 & \checkmark   & 57% & 0 \\
# HD 20794 e           & 0.5090 & 2.03 & 2.6 & 2.7 & \checkmark   & 36% & 0 \\
# HD 10700 e           & 0.5380 & 1.81 & 4.6 & 1.3 & \checkmark   & 31% & 0 \\
# HD 10700 f           & 1.3340 & 1.81 & 1.1e+03 & 0.0054 & ---          & 0% & 0.21 \\
# \hline
# \end{tabular}
# \end{table}
#
# ======================================================================
#   5e. BATCH RM MCMC - Per-Planet RV Anomaly
# ======================================================================
#
#   RM [  1/70] HD 3651 b ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=3.54 lam=7.2 b=0.31 drv=-0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:03<00:00, 157.75it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 3.54 km/s
#   lambda  = 7.3 deg
#   b       = 0.311
#   drv0    = -0.0002 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_3651_b_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_3651_b_corner.png
# v_si=3.54 lam=+7.3d (true=+10.2d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_3651_b_rv.png
#   RM [  2/70] HD 9826 b ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=5.61 lam=-15.7 b=0.30 drv=-0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:01<00:00, 163.33it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 5.61 km/s
#   lambda  = -15.8 deg
#   b       = 0.295
#   drv0    = -0.0001 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_9826_b_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_9826_b_corner.png
# v_si=5.61 lam=-15.8d (true=-11.0d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_9826_b_rv.png
#   RM [  3/70] HD 9826 c ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=5.35 lam=10.9 b=0.30 drv=-0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:02<00:00, 159.65it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 5.36 km/s
#   lambda  = 10.8 deg
#   b       = 0.299
#   drv0    = -0.0002 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_9826_c_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_9826_c_corner.png
# v_si=5.36 lam=+10.8d (true=+12.1d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_9826_c_rv.png
#   RM [  4/70] HD 9826 d ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=5.40 lam=4.0 b=0.31 drv=-0.003
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:01<00:00, 162.01it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 5.39 km/s
#   lambda  = 4.1 deg
#   b       = 0.305
#   drv0    = -0.0027 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_9826_d_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_9826_d_corner.png
# v_si=5.39 lam=+4.1d (true=+7.1d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_9826_d_rv.png
#   RM [  5/70] HD 10647 b ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=14.93 lam=-18.0 b=0.30 drv=0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:02<00:00, 160.63it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 14.93 km/s
#   lambda  = -17.9 deg
#   b       = 0.304
#   drv0    = 0.0000 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_10647_b_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_10647_b_corner.png
# v_si=14.93 lam=-17.9d (true=-19.4d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_10647_b_rv.png
#   RM [  6/70] HD 10700 g ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=3.72 lam=8.2 b=0.36 drv=-0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [00:59<00:00, 168.28it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 3.76 km/s
#   lambda  = 8.9 deg
#   b       = 0.350
#   drv0    = -0.0000 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_10700_g_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_10700_g_corner.png
# v_si=3.76 lam=+8.9d (true=+9.1d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_10700_g_rv.png
#   RM [  7/70] HD 10700 h ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=3.26 lam=-15.8 b=0.38 drv=-0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [00:58<00:00, 172.14it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 3.29 km/s
#   lambda  = -16.7 deg
#   b       = 0.349
#   drv0    = -0.0000 km/s
# WARNING:root:Too few points to create valid contours
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_10700_h_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_10700_h_corner.png
# v_si=3.29 lam=-16.7d (true=-16.8d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_10700_h_rv.png
#   RM [  8/70] HD 10700 e ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=3.79 lam=-2.2 b=0.31 drv=-0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:03<00:00, 158.70it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 3.81 km/s
#   lambda  = -2.2 deg
#   b       = 0.315
#   drv0    = -0.0000 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_10700_e_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_10700_e_corner.png
# v_si=3.81 lam=-2.2d (true=-1.5d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_10700_e_rv.png
#   RM [  9/70] HD 10700 f ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=3.58 lam=-18.8 b=0.28 drv=-0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:05<00:00, 153.23it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 3.58 km/s
#   lambda  = -18.8 deg
#   b       = 0.283
#   drv0    = -0.0000 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_10700_f_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_10700_f_corner.png
# v_si=3.58 lam=-18.8d (true=-13.8d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_10700_f_rv.png
#   RM [ 10/70] HD 17051 b ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=5.60 lam=18.7 b=0.29 drv=0.001
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:01<00:00, 161.34it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 5.60 km/s
#   lambda  = 18.7 deg
#   b       = 0.294
#   drv0    = 0.0007 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_17051_b_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_17051_b_corner.png
# v_si=5.60 lam=+18.7d (true=+15.0d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_17051_b_rv.png
#   RM [ 11/70] HD 20794 b ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=3.60 lam=7.9 b=0.27 drv=0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [00:59<00:00, 168.41it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 3.63 km/s
#   lambda  = 8.2 deg
#   b       = 0.267
#   drv0    = 0.0000 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_20794_b_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_20794_b_corner.png
# v_si=3.63 lam=+8.2d (true=+4.3d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_20794_b_rv.png
#   RM [ 12/70] HD 20794 c ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=3.53 lam=8.8 b=0.32 drv=-0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:02<00:00, 159.17it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 3.55 km/s
#   lambda  = 8.6 deg
#   b       = 0.321
#   drv0    = -0.0000 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_20794_c_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_20794_c_corner.png
# v_si=3.55 lam=+8.6d (true=+10.1d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_20794_c_rv.png
#   RM [ 13/70] HD 20794 d ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=3.47 lam=-9.2 b=0.29 drv=0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:02<00:00, 159.47it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 3.48 km/s
#   lambda  = -9.1 deg
#   b       = 0.290
#   drv0    = 0.0000 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_20794_d_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_20794_d_corner.png
# v_si=3.48 lam=-9.2d (true=-7.9d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_20794_d_rv.png
#   RM [ 14/70] HD 20794 e ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=3.50 lam=-8.7 b=0.30 drv=-0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:03<00:00, 158.44it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 3.50 km/s
#   lambda  = -8.7 deg
#   b       = 0.301
#   drv0    = -0.0000 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_20794_e_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_20794_e_corner.png
# v_si=3.50 lam=-8.7d (true=-9.0d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_20794_e_rv.png
#   RM [ 15/70] HD 22049 b ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=2.46 lam=-9.2 b=0.29 drv=0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:02<00:00, 159.18it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 2.46 km/s
#   lambda  = -9.2 deg
#   b       = 0.288
#   drv0    = 0.0000 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_22049_b_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_22049_b_corner.png
# v_si=2.46 lam=-9.2d (true=-12.3d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_22049_b_rv.png
#   RM [ 16/70] HD 26965 b ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=2.44 lam=7.0 b=0.31 drv=-0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:00<00:00, 165.34it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 2.44 km/s
#   lambda  = 7.0 deg
#   b       = 0.313
#   drv0    = -0.0000 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_26965_b_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_26965_b_corner.png
# v_si=2.44 lam=+7.0d (true=+8.5d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_26965_b_rv.png
#   RM [ 17/70] HD 33564 b ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=14.71 lam=-0.2 b=0.29 drv=-0.003
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:00<00:00, 166.10it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 14.70 km/s
#   lambda  = -0.2 deg
#   b       = 0.283
#   drv0    = -0.0029 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_33564_b_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_33564_b_corner.png
# v_si=14.70 lam=-0.2d (true=-0.7d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_33564_b_rv.png
#   RM [ 18/70] HD 39091 c ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=5.76 lam=19.1 b=0.29 drv=0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:05<00:00, 152.62it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 5.77 km/s
#   lambda  = 19.1 deg
#   b       = 0.286
#   drv0    = 0.0000 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_39091_c_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_39091_c_corner.png
# v_si=5.77 lam=+19.1d (true=+15.9d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_39091_c_rv.png
#   RM [ 19/70] HD 39091 d ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=5.54 lam=-1.5 b=0.30 drv=0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:04<00:00, 153.96it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 5.53 km/s
#   lambda  = -1.5 deg
#   b       = 0.303
#   drv0    = 0.0000 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_39091_d_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_39091_d_corner.png
# v_si=5.53 lam=-1.4d (true=-3.0d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_39091_d_rv.png
#   RM [ 20/70] HD 39091 b ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=5.46 lam=14.7 b=0.30 drv=0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:05<00:00, 153.60it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 5.46 km/s
#   lambda  = 14.9 deg
#   b       = 0.296
#   drv0    = 0.0004 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_39091_b_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_39091_b_corner.png
# v_si=5.46 lam=+14.9d (true=+15.3d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_39091_b_rv.png
#   RM [ 21/70] HD 69830 b ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=3.48 lam=-18.6 b=0.29 drv=-0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:03<00:00, 157.58it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 3.48 km/s
#   lambda  = -18.8 deg
#   b       = 0.290
#   drv0    = -0.0000 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_69830_b_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_69830_b_corner.png
# v_si=3.48 lam=-18.8d (true=-17.7d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_69830_b_rv.png
#   RM [ 22/70] HD 69830 c ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=3.52 lam=-12.4 b=0.30 drv=-0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:03<00:00, 156.50it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 3.52 km/s
#   lambda  = -12.4 deg
#   b       = 0.303
#   drv0    = -0.0000 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_69830_c_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_69830_c_corner.png
# v_si=3.52 lam=-12.4d (true=-14.6d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_69830_c_rv.png
#   RM [ 23/70] HD 69830 d ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=3.55 lam=3.6 b=0.31 drv=0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:03<00:00, 157.77it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 3.55 km/s
#   lambda  = 3.6 deg
#   b       = 0.313
#   drv0    = 0.0000 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_69830_d_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_69830_d_corner.png
# v_si=3.55 lam=+3.6d (true=+2.2d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_69830_d_rv.png
#   RM [ 24/70] HD 75732 e ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=2.54 lam=-3.0 b=0.30 drv=0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:03<00:00, 157.89it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 2.54 km/s
#   lambda  = -2.9 deg
#   b       = 0.297
#   drv0    = 0.0000 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_75732_e_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_75732_e_corner.png
# v_si=2.54 lam=-2.9d (true=-3.3d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_75732_e_rv.png
#   RM [ 25/70] HD 75732 b ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=2.48 lam=14.7 b=0.30 drv=0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:02<00:00, 160.25it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 2.48 km/s
#   lambda  = 14.6 deg
#   b       = 0.299
#   drv0    = 0.0000 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_75732_b_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_75732_b_corner.png
# v_si=2.48 lam=+14.6d (true=+13.0d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_75732_b_rv.png
#   RM [ 26/70] HD 75732 c ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=2.49 lam=-8.8 b=0.29 drv=-0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:03<00:00, 158.55it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 2.49 km/s
#   lambda  = -8.8 deg
#   b       = 0.287
#   drv0    = -0.0001 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_75732_c_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_75732_c_corner.png
# v_si=2.49 lam=-8.8d (true=-6.6d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_75732_c_rv.png
#   RM [ 27/70] HD 75732 f ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=2.54 lam=17.9 b=0.29 drv=0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:05<00:00, 153.63it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 2.54 km/s
#   lambda  = 18.1 deg
#   b       = 0.291
#   drv0    = 0.0001 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_75732_f_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_75732_f_corner.png
# v_si=2.54 lam=+18.1d (true=+13.4d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_75732_f_rv.png
#   RM [ 28/70] HD 75732 d ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=2.53 lam=21.2 b=0.31 drv=0.002
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:05<00:00, 152.93it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 2.53 km/s
#   lambda  = 21.4 deg
#   b       = 0.309
#   drv0    = 0.0021 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_75732_d_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_75732_d_corner.png
# v_si=2.53 lam=+21.4d (true=+17.0d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_75732_d_rv.png
#   RM [ 29/70] HD 95128 b ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=5.49 lam=1.0 b=0.30 drv=0.001
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:11<00:00, 139.85it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 5.49 km/s
#   lambda  = 1.0 deg
#   b       = 0.299
#   drv0    = 0.0008 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_95128_b_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_95128_b_corner.png
# v_si=5.49 lam=+1.0d (true=+1.0d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_95128_b_rv.png
#   RM [ 30/70] HD 95128 c ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=5.36 lam=12.1 b=0.29 drv=0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:05<00:00, 153.59it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 5.36 km/s
#   lambda  = 12.1 deg
#   b       = 0.290
#   drv0    = 0.0000 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_95128_c_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_95128_c_corner.png
# v_si=5.36 lam=+12.1d (true=+12.5d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_95128_c_rv.png
#   RM [ 31/70] HD 95128 d ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=5.41 lam=1.1 b=0.30 drv=-0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:03<00:00, 156.32it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 5.42 km/s
#   lambda  = 1.1 deg
#   b       = 0.297
#   drv0    = -0.0002 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_95128_d_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_95128_d_corner.png
# v_si=5.42 lam=+1.1d (true=+1.2d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_95128_d_rv.png
#   RM [ 32/70] HD 95735 b ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=1.03 lam=19.2 b=0.32 drv=0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:04<00:00, 155.60it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 1.04 km/s
#   lambda  = 19.5 deg
#   b       = 0.309
#   drv0    = 0.0000 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_95735_b_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_95735_b_corner.png
# v_si=1.04 lam=+19.5d (true=+19.4d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_95735_b_rv.png
#   RM [ 33/70] HD 95735 c ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=0.99 lam=19.2 b=0.30 drv=0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:06<00:00, 151.41it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 0.99 km/s
#   lambda  = 19.1 deg
#   b       = 0.302
#   drv0    = 0.0000 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_95735_c_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_95735_c_corner.png
# v_si=0.99 lam=+19.1d (true=+18.4d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_95735_c_rv.png
#   RM [ 34/70] HD 102365 b ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=3.54 lam=-2.5 b=0.31 drv=-0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:02<00:00, 160.07it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 3.55 km/s
#   lambda  = -2.5 deg
#   b       = 0.305
#   drv0    = -0.0001 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_102365_b_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_102365_b_corner.png
# v_si=3.54 lam=-2.5d (true=+1.7d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_102365_b_rv.png
#   RM [ 35/70] HD 114613 b ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=3.52 lam=-10.5 b=0.30 drv=-0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:23<00:00, 120.39it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 3.52 km/s
#   lambda  = -10.4 deg
#   b       = 0.301
#   drv0    = -0.0004 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_114613_b_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_114613_b_corner.png
# v_si=3.52 lam=-10.4d (true=-9.0d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_114613_b_rv.png
#   RM [ 36/70] HD 115404A b ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=2.55 lam=7.5 b=0.33 drv=-0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:00<00:00, 164.18it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 2.55 km/s
#   lambda  = 7.5 deg
#   b       = 0.324
#   drv0    = -0.0001 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_115404A_b_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_115404A_b_corner.png
# v_si=2.55 lam=+7.5d (true=+10.4d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_115404A_b_rv.png
#   RM [ 37/70] HD 115404A c ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=2.47 lam=-4.0 b=0.29 drv=0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [00:57<00:00, 173.21it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 2.47 km/s
#   lambda  = -4.0 deg
#   b       = 0.287
#   drv0    = 0.0002 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_115404A_c_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_115404A_c_corner.png
# v_si=2.47 lam=-4.0d (true=-3.3d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_115404A_c_rv.png
#   RM [ 38/70] HD 115617 b ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=3.49 lam=11.7 b=0.25 drv=0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [00:57<00:00, 173.37it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 3.50 km/s
#   lambda  = 11.9 deg
#   b       = 0.250
#   drv0    = 0.0001 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_115617_b_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_115617_b_corner.png
# v_si=3.50 lam=+11.9d (true=+2.1d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_115617_b_rv.png
#   RM [ 39/70] HD 115617 c ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=3.44 lam=-9.1 b=0.30 drv=0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [00:57<00:00, 174.75it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 3.44 km/s
#   lambda  = -9.1 deg
#   b       = 0.296
#   drv0    = 0.0000 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_115617_c_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_115617_c_corner.png
# ...
#   RM [ 57/70] HD 189567 c ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=3.45 lam=-13.8 b=0.29 drv=-0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:00<00:00, 165.95it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 3.46 km/s
#   lambda  = -13.8 deg
#   b       = 0.288
#   drv0    = -0.0000 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_189567_c_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_189567_c_corner.png
# v_si=3.46 lam=-13.8d (true=-13.7d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_189567_c_rv.png
#   RM [ 58/70] HD 190360 c ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=3.41 lam=-17.2 b=0.31 drv=0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:00<00:00, 166.11it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 3.42 km/s
#   lambda  = -17.3 deg
#   b       = 0.305
#   drv0    = 0.0000 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_190360_c_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_190360_c_corner.png
# v_si=3.42 lam=-17.3d (true=-18.4d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_190360_c_rv.png
#   RM [ 59/70] HD 190360 b ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=3.46 lam=2.1 b=0.28 drv=-0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [00:59<00:00, 168.55it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 3.46 km/s
#   lambda  = 2.1 deg
#   b       = 0.277
#   drv0    = -0.0001 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_190360_b_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_190360_b_corner.png
# v_si=3.46 lam=+2.1d (true=+1.4d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_190360_b_rv.png
#   RM [ 60/70] HD 192310 b ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=2.44 lam=14.4 b=0.30 drv=-0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:00<00:00, 165.94it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 2.44 km/s
#   lambda  = 14.4 deg
#   b       = 0.298
#   drv0    = -0.0000 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_192310_b_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_192310_b_corner.png
# v_si=2.44 lam=+14.4d (true=+16.3d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_192310_b_rv.png
#   RM [ 61/70] HD 192310 c ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=2.52 lam=-0.8 b=0.29 drv=0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:03<00:00, 158.63it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 2.52 km/s
#   lambda  = -0.8 deg
#   b       = 0.288
#   drv0    = 0.0000 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_192310_c_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_192310_c_corner.png
# v_si=2.52 lam=-0.8d (true=-2.6d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_192310_c_rv.png
#   RM [ 62/70] HD 209100 b ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=2.51 lam=-17.4 b=0.27 drv=-0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:02<00:00, 160.92it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 2.52 km/s
#   lambda  = -17.7 deg
#   b       = 0.268
#   drv0    = -0.0005 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_209100_b_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_209100_b_corner.png
# v_si=2.52 lam=-17.7d (true=-15.7d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_209100_b_rv.png
#   RM [ 63/70] HD 217987 b ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=1.06 lam=-3.8 b=0.32 drv=-0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:04<00:00, 155.86it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 1.06 km/s
#   lambda  = -3.9 deg
#   b       = 0.312
#   drv0    = -0.0000 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_217987_b_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_217987_b_corner.png
# v_si=1.06 lam=-3.9d (true=-2.4d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_217987_b_rv.png
#   RM [ 64/70] HD 217987 c ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=1.03 lam=-8.2 b=0.30 drv=0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:04<00:00, 155.89it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 1.03 km/s
#   lambda  = -8.1 deg
#   b       = 0.296
#   drv0    = 0.0001 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_217987_c_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_217987_c_corner.png
# v_si=1.03 lam=-8.1d (true=-12.2d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_217987_c_rv.png
#   RM [ 65/70] HD 219134 b ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=2.48 lam=5.4 b=0.28 drv=0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:03<00:00, 158.01it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 2.48 km/s
#   lambda  = 5.7 deg
#   b       = 0.263
#   drv0    = 0.0000 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_219134_b_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_219134_b_corner.png
# v_si=2.48 lam=+5.7d (true=+10.1d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_219134_b_rv.png
#   RM [ 66/70] HD 219134 c ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=2.34 lam=-8.3 b=0.28 drv=-0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:00<00:00, 165.04it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 2.38 km/s
#   lambda  = -9.8 deg
#   b       = 0.262
#   drv0    = -0.0001 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_219134_c_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_219134_c_corner.png
# v_si=2.38 lam=-9.8d (true=+11.1d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_219134_c_rv.png
#   RM [ 67/70] HD 219134 f ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=2.58 lam=22.9 b=0.29 drv=0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:02<00:00, 160.86it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 2.58 km/s
#   lambda  = 22.8 deg
#   b       = 0.293
#   drv0    = 0.0000 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_219134_f_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_219134_f_corner.png
# v_si=2.58 lam=+22.8d (true=+19.6d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_219134_f_rv.png
#   RM [ 68/70] HD 219134 d ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=2.53 lam=-0.5 b=0.29 drv=-0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:01<00:00, 161.37it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 2.53 km/s
#   lambda  = -0.5 deg
#   b       = 0.290
#   drv0    = -0.0001 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_219134_d_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_219134_d_corner.png
# v_si=2.53 lam=-0.5d (true=+1.1d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_219134_d_rv.png
#   RM [ 69/70] HD 219134 g ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=2.49 lam=-14.7 b=0.29 drv=-0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:03<00:00, 156.38it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 2.49 km/s
#   lambda  = -14.7 deg
#   b       = 0.290
#   drv0    = -0.0000 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_219134_g_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_219134_g_corner.png
# v_si=2.49 lam=-14.7d (true=-14.6d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_219134_g_rv.png
#   RM [ 70/70] HD 219134 h ... [RMSolverMCMCExtended] Pre-fitting (4-param)...
#   Seed: v=2.48 lam=4.2 b=0.31 drv=-0.000
# [RMSolverMCMCExtended] Running 10000 steps...
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:03<00:00, 157.63it/s]
# [RMSolverMCMCExtended] Done.
#   v sin i = 2.47 km/s
#   lambda  = 4.2 deg
#   b       = 0.303
#   drv0    = -0.0002 km/s
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_219134_h_rv.png
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_219134_h_corner.png
# v_si=2.48 lam=+4.2d (true=+2.8d) -> C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly\HD_219134_h_rv.png
#   Batch results saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\batch_results_with_rm.csv
#   Locked: 41/70 planets
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\rv_anomaly_gallery.png
#
# ======================================================================
#   5f. DOPPLER DECOMPOSITION - Rotation vs Super-Rotation
# ======================================================================
#
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\doppler_decomposition.png
#   Rotation-dominated planets: 1/70
#   Mean dv_total = 0.3920 km/s
#
# ======================================================================
#   5g. DETECTION FEASIBILITY RANKING
# ======================================================================
#
#
# ==============================================================================
#   DETECTION FEASIBILITY RANKING  (top 20)
# ==============================================================================
#   Rank  Planet                 Dv (km/s)    sigma_v      N_transits   Feasible?
# ------------------------------------------------------------------------------
#   1     HD 33564 b             1.8520       0.19936      1            YES
#   2     HD 140901 c            0.8294       0.11562      1            YES
#   3     HD 115404A c           0.8585       0.09198      1            YES
#   4     HD 39091 b             1.6221       0.12036      1            YES
#   5     HD 209100 b            0.4511       0.11561      2            YES
#   6     HD 9826 d              0.9631       0.19548      2            YES
#   7     HD 95128 b             0.7357       0.17204      2            YES
#   8     HD 75732 d             0.5727       0.13805      2            YES
#   9     HD 3651 b              0.8472       0.24366      3            YES
#   10    HD 190360 b            0.4639       0.15639      3            YES
#   11    HD 160691 c            0.5093       0.16252      3            YES
#   12    HD 160691 b            0.6496       0.22101      3            YES
#   13    HD 143761 b            0.8247       0.26803      3            YES
#   14    HD 95128 d             0.3864       0.11494      3            YES
#   15    HD 219134 h            0.5125       0.15427      3            YES
#   16    HD 9826 c              0.8923       0.27084      3            YES
#   17    HD 17051 b             0.9255       0.27746      3            YES
#   18    HD 75732 c             0.8241       0.32630      4            YES
#   19    HD 114613 b            0.5389       0.20508      4            YES
#   20    HD 143761 c            0.6416       0.23042      4            YES
# ==============================================================================
#   Saved: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch\detection_feasibility.png
#
#   Batch outputs saved to: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2\batch
#
# ======================================================================
#   MODULE 2 COMPLETE
# ======================================================================
#
#   All outputs saved to: C:\Users\asmit\OneDrive\Desktop\astro_project\term_project1\module_2_tidal_rotation\..\output_plots\module2
